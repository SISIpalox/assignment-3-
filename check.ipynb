# %%
# Adjusting the game for when there are only papers numbered 1 to 7
import numpy as np
def play_game(numbers):
    while len(numbers) > 1:
        # Randomly select two numbers
        chosen_idx = np.random.choice(len(numbers), 2, replace=False)
        chosen_numbers = [numbers[chosen_idx[0]], numbers[chosen_idx[1]]]
        # Calculate the difference between the two numbers
        diff = abs(chosen_numbers[0] - chosen_numbers[1])
        # Remove the chosen numbers from the list
        numbers = [num for i, num in enumerate(numbers) if i not in chosen_idx]
        # Put the difference back into the list
        numbers.append(diff)
    # Return the last remaining number in the list
    return numbers[0]

# Initialize a list to store the final numbers
final_numbers_1_to_7 = []

# Play the game 50 times with numbers 1 to 7
for _ in range(50):
    numbers = list(range(1, 8))
    final_number = play_game(numbers)
    final_numbers_1_to_7.append(final_number)

final_numbers_1_to_7
# Out:
# [0,
#  6,
#  2,
#  4,
#  0,
#  2,
#  2,
#  2,
#  0,
#  2,
#  4,
#  2,
#  4,
#  0,
#  2,
#  2,
#  2,
#  6,
#  0,
#  2,
#  0,
#  0,
#  0,
#  2,
#  4,
#  2,
#  0,
#  0,
#  6,
#  4,
#  6,
#  0,
#  4,
#  4,
#  4,
#  2,
#  0,
#  4,
#  6,
#  4,
#  4,
#  0,
#  2,
#  2,
#  2,
#  0,
#  2,
#  0,
#  0,
#  2]

# %%
# Adjusting the game for when there are only papers numbered 1 to 8
import numpy as np
def play_game(numbers):
    while len(numbers) > 1:
        # Randomly select two numbers
        chosen_idx = np.random.choice(len(numbers), 2, replace=False)
        chosen_numbers = [numbers[chosen_idx[0]], numbers[chosen_idx[1]]]
        # Calculate the difference between the two numbers
        diff = abs(chosen_numbers[0] - chosen_numbers[1])
        # Remove the chosen numbers from the list
        numbers = [num for i, num in enumerate(numbers) if i not in chosen_idx]
        # Put the difference back into the list
        numbers.append(diff)
    # Return the last remaining number in the list
    return numbers[0]

# Initialize a list to store the final numbers
final_numbers_1_to_8 = []

# Play the game 50 times with numbers 1 to 8
for _ in range(50):
    numbers = list(range(1, 9))
    final_number = play_game(numbers)
    final_numbers_1_to_8.append(final_number)

final_numbers_1_to_8
# Out:
# [0,
#  2,
#  0,
#  2,
#  4,
#  2,
#  2,
#  6,
#  2,
#  0,
#  2,
#  2,
#  4,
#  4,
#  0,
#  2,
#  0,
#  2,
#  2,
#  8,
#  2,
#  4,
#  2,
#  2,
#  4,
#  2,
#  2,
#  2,
#  2,
#  0,
#  0,
#  2,
#  2,
#  2,
#  6,
#  2,
#  0,
#  2,
#  0,
#  4,
#  0,
#  0,
#  0,
#  0,
#  2,
#  6,
#  0,
#  4,
#  4,
#  0]
